# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Pre-processing" data-toc-modified-id="Pre-processing-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Pre-processing</a></span><ul class="toc-item"><li><span><a href="#Categorical-Data" data-toc-modified-id="Categorical-Data-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Categorical Data</a></span></li><li><span><a href="#Numerical-Features" data-toc-modified-id="Numerical-Features-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Numerical Features</a></span></li><li><span><a href="#Select-Column-with-Nominal-composition" data-toc-modified-id="Select-Column-with-Nominal-composition-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Select Column with Nominal composition</a></span></li><li><span><a href="#Drop-columns-with-zero-standard-deviation" data-toc-modified-id="Drop-columns-with-zero-standard-deviation-1.4"><span class="toc-item-num">1.4&nbsp;&nbsp;</span>Drop columns with zero standard deviation</a></span></li><li><span><a href="#Highly-correlated-features" data-toc-modified-id="Highly-correlated-features-1.5"><span class="toc-item-num">1.5&nbsp;&nbsp;</span>Highly correlated features</a></span></li></ul></li><li><span><a href="#Data-visulaization" data-toc-modified-id="Data-visulaization-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Data visulaization</a></span><ul class="toc-item"><li><span><a href="#Temper-method" data-toc-modified-id="Temper-method-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Temper method</a></span></li><li><span><a href="#Processing-Method" data-toc-modified-id="Processing-Method-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Processing Method</a></span></li></ul></li><li><span><a href="#Features-Engineering" data-toc-modified-id="Features-Engineering-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Features Engineering</a></span><ul class="toc-item"><li><span><a href="#Target-Variable-Analysis:--Is-it-Normal?" data-toc-modified-id="Target-Variable-Analysis:--Is-it-Normal?-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Target Variable Analysis:  Is it Normal?</a></span><ul class="toc-item"><li><span><a href="#Ultimate-tensile-strength" data-toc-modified-id="Ultimate-tensile-strength-3.1.1"><span class="toc-item-num">3.1.1&nbsp;&nbsp;</span>Ultimate tensile strength</a></span></li><li><span><a href="#Tensile-yield-strength" data-toc-modified-id="Tensile-yield-strength-3.1.2"><span class="toc-item-num">3.1.2&nbsp;&nbsp;</span>Tensile yield strength</a></span></li></ul></li><li><span><a href="#Normalize-Target" data-toc-modified-id="Normalize-Target-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Normalize Target</a></span></li></ul></li><li><span><a href="#Model" data-toc-modified-id="Model-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Model</a></span></li><li><span><a href="#Random-Forest-Regression" data-toc-modified-id="Random-Forest-Regression-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Random Forest Regression</a></span><ul class="toc-item"><li><span><a href="#Features-selection" data-toc-modified-id="Features-selection-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>Features selection</a></span></li><li><span><a href="#Grid-Search--with-Cross-Validation" data-toc-modified-id="Grid-Search--with-Cross-Validation-5.2"><span class="toc-item-num">5.2&nbsp;&nbsp;</span>Grid Search  with Cross Validation</a></span></li><li><span><a href="#Evaluate-Final-Model-on-the-Test-Set" data-toc-modified-id="Evaluate-Final-Model-on-the-Test-Set-5.3"><span class="toc-item-num">5.3&nbsp;&nbsp;</span>Evaluate Final Model on the Test Set</a></span></li></ul></li><li><span><a href="#Gradient-boosting-machine-(GBM)--Regression" data-toc-modified-id="Gradient-boosting-machine-(GBM)--Regression-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Gradient boosting machine (GBM)  Regression</a></span><ul class="toc-item"><li><span><a href="#Explore-Number-of-Trees" data-toc-modified-id="Explore-Number-of-Trees-6.1"><span class="toc-item-num">6.1&nbsp;&nbsp;</span>Explore Number of Trees</a></span></li><li><span><a href="#Learning-Rate" data-toc-modified-id="Learning-Rate-6.2"><span class="toc-item-num">6.2&nbsp;&nbsp;</span>Learning Rate</a></span></li><li><span><a href="#Tree-Depth" data-toc-modified-id="Tree-Depth-6.3"><span class="toc-item-num">6.3&nbsp;&nbsp;</span>Tree Depth</a></span></li><li><span><a href="#Grid-Search-Hyperparameters" data-toc-modified-id="Grid-Search-Hyperparameters-6.4"><span class="toc-item-num">6.4&nbsp;&nbsp;</span>Grid Search Hyperparameters</a></span></li><li><span><a href="#Evaluate-Final-Model-on-the-Test-Set" data-toc-modified-id="Evaluate-Final-Model-on-the-Test-Set-6.5"><span class="toc-item-num">6.5&nbsp;&nbsp;</span>Evaluate Final Model on the Test Set</a></span></li></ul></li><li><span><a href="#confidence-interval" data-toc-modified-id="confidence-interval-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>confidence interval</a></span></li></ul></div>

# %%
import matplotlib.pyplot as plt
from matplotlib.image import imread
import pandas as pd
import seaborn as sns; sns.set()
from sklearn.datasets import (make_blobs,make_circles,make_moons)
from sklearn.cluster import KMeans, SpectralClustering
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import silhouette_samples, silhouette_score
from sklearn.model_selection import RandomizedSearchCV, train_test_split,GridSearchCV
#import missingno as msno
# %matplotlib inline
from warnings import filterwarnings
import csv
filterwarnings('ignore')

# %%
# Prints Data
data = pd.read_csv('AlAlloysBD_preprocessed.csv')
data.info(verbose = True, null_counts = True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2322 entries, 0 to 2321
# Data columns (total 124 columns):
#  #    Column                                                           Non-Null Count  Dtype
# ---   ------                                                           --------------  -----
#  0    Alloy Series type                                                2318 non-null   object
#  1    temper method                                                    2074 non-null   object
#  2    Cold Rolling reduction (%)                                       97 non-null     float64
#  3    Component part shape                                             272 non-null    object
#  4    Processing Method                                                2136 non-null   object
#  5    Initial Temperature (Celcius)                                    1328 non-null   float64
#  6    Final Temperature (Celcius)                                      1328 non-null   float64
# ...

# %%
data.head()
# Out:
#   Alloy Series type temper method  Cold Rolling reduction (%)  \
# 0              1050             O                         NaN
# 1              1050             O                         NaN
# 2              1050             O                         NaN
# 3              1050             O                         NaN
# 4              1050             O                         NaN
#
#   Component part shape Processing Method  Initial Temperature (Celcius)  \
# 0                  NaN           Wrought                          -50.0
# 1                  NaN           Wrought                           20.0
# 2                  NaN           Wrought                           20.0
# 3                  NaN           Wrought                           20.0
# 4                  NaN           Wrought                            NaN
#
#    Final Temperature (Celcius)  Average Temperature (Celcius)  \
# 0                         20.0                          -15.0
# ...

# %%
msno.bar(data[['Ultimate tensile strength  (MPa)','Tensile yield strength at 0.2% offset  (MPa)']] )
# Out:
# <AxesSubplot:>

# %%
df_Ultimate_tensile = data.loc[data['Ultimate tensile strength  (MPa)'].notnull(), data.columns]
len(df_Ultimate_tensile)
# Out:
# 1369

# %%
df_Tensile_yield = data.loc[data['Tensile yield strength at 0.2% offset  (MPa)'].notnull(), data.columns]
len(df_Tensile_yield)
# Out:
# 1346

# %%
df_tensile= data.loc[(data['Ultimate tensile strength  (MPa)'].notnull())& (data['Tensile yield strength at 0.2% offset  (MPa)'].notnull()), data.columns]
len(df_tensile)
# Out:
# 1102

# %%
df_tensile.to_csv('Data_tensile/data_tensile.csv',index=False)

# %% [markdown]
# ## Pre-processing

# %% [markdown]
# ### Categorical Data

# %%
categorical_cols_name = df_tensile.select_dtypes(exclude=np.number).columns.tolist()
data_categorical = df_tensile.select_dtypes(exclude=np.number)
msno.bar(data_categorical, figsize=(12, 6), fontsize=12, color='steelblue')
# Out:
# <AxesSubplot:>

# %%
CAT = data_categorical.loc[:,data_categorical.isnull().mean()<.8]

# %%
from sklearn.preprocessing import OrdinalEncoder
CAT_ordinal = CAT.copy(deep=True)
# Create dictionary for Ordinal encoders
ordinal_enc_dict = {}
  # Loop over columns to encode
for col_name in CAT:
  # Create ordinal encoder for the column 
  ordinal_enc_dict[col_name] = OrdinalEncoder()

  # Select the nin-null values in the column
  col = CAT[col_name]
  col_not_null = col[col.notnull()]
  reshaped_vals = col_not_null.values.reshape(-1, 1)

  # Encode the non-null values of the column
  encoded_vals = ordinal_enc_dict[col_name].fit_transform(reshaped_vals)
  
  ##Replace the column with ordinal values

  CAT_ordinal.loc[col.notnull(),col_name]  =np.squeeze(encoded_vals)
  print('+Encode: {} '.format(col_name))
# Out:
# +Encode: Alloy Series type
# +Encode: temper method
# +Encode: Processing Method
# +Encode: Standardized Composition

# %%
from sklearn.impute import KNNImputer
KNN_imputer = KNNImputer(n_neighbors=3)
import warnings
warnings.filterwarnings('ignore')
CAT_KNN = CAT_ordinal.copy(deep=True) # Create MICE imputer
CAT_KNN.iloc[:, :] = np.round(KNN_imputer.fit_transform(CAT_KNN))

# %%
for col in CAT_KNN:
  reshaped_col = CAT_KNN[col].values.reshape(-1, 1)
  print('inverse_transform: {}'.format(col))
  CAT_KNN[col] = ordinal_enc_dict[col].inverse_transform(reshaped_col)
# Out:
# inverse_transform: Alloy Series type
# inverse_transform: temper method
# inverse_transform: Processing Method
# inverse_transform: Standardized Composition

# %%
msno.bar(CAT_KNN, figsize=(4,4), fontsize=12, color='steelblue')
CAT_KNN.to_csv('Data_tensile/CAT_Inputed_KNN.csv', index=False)

# %% [markdown]
# ### Numerical Features

# %%
numerics_cols_name = df_tensile.select_dtypes(include=np.number).columns.tolist()
data_numerics = df_tensile.select_dtypes(include=np.number)

# %%
element_col= [name for name in numerics_cols_name if ('Nominal'  in name) or  ('Maximum'  in name) or ('Minimum' in name)]

# %%
NUM_1 = data_numerics.drop(columns=element_col)

# %%
msno.bar(NUM_1, figsize=(12, 6), fontsize=12, color='steelblue')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Select Column with Nominal composition

# %%
element_col= [name for name in numerics_cols_name if ('Nominal'  in name) ]
target_col = ['Ultimate tensile strength  (MPa)','Tensile yield strength at 0.2% offset  (MPa)']
NUM_2 = data_numerics [element_col +target_col]

# %% [markdown]
# ### Drop columns with zero standard deviation

# %%
drop_std=NUM_2.drop(NUM_2.std()[NUM_2.std()==0.0].index.values, axis=1)

# %%
print('Len data_numerics:', NUM_2.shape )
print('Len drop_std:' ,  drop_std.shape)
# Out:
# Len data_numerics: (1102, 31)
# Len drop_std: (1102, 25)

# %%
msno.bar(NUM_2, figsize=(12, 6), fontsize=12, color='steelblue')
# Out:
# <AxesSubplot:>

# %%
df_cat = CAT_KNN[['temper method','Processing Method' ]]

# %%
df_preprocessed = pd.concat([df_cat, NUM_2], axis=1, join="inner")

# %%
msno.bar(df_preprocessed, figsize=(12, 6), fontsize=12, color='steelblue')
# Out:
# <AxesSubplot:>

# %%
df_preprocessed.to_csv('Data_tensile/data_tensile_processed.csv', index=False)

# %%
df_preprocessed.head()
# Out:
#    temper method Processing Method  Al Nominal  Si Nominal  Fe+Ni Nominal  \
# 4              O           Wrought      99.775       0.125              0
# 5            H14           Wrought      99.775       0.125              0
# 6            H16           Wrought      99.775       0.125              0
# 7            H18           Wrought      99.775       0.125              0
# 12             O           Wrought      99.775       0.125              0
#
#     Fe Nominal  Si+Fe Nominal  Si+Cu Nominal   Cu Nominal  Cd Nominal  ...  \
# 4        0.000            0.0               0       0.025         0.0  ...
# 5        0.000            0.0               0       0.025         0.0  ...
# 6        0.000            0.0               0       0.025         0.0  ...
# 7        0.000            0.0               0       0.025         0.0  ...
# 12       0.175            0.0               0       0.025         0.0  ...
#
# ...

# %% [markdown]
# ### Highly correlated features

# %%
# Absolute value correlation matrix
corr_matrix = drop_std.corr().abs()

# Upper triangle of correlations
upper = corr_matrix.where(np.triu(np.ones(corr_matrix.shape), k=1).astype(np.bool))

# %%
# corr_matrix.style.background_gradient(cmap='coolwarm').set_precision(2)

# %%
f, ax = plt.subplots(figsize=(10, 8))
sns.heatmap(corr_matrix, mask=np.zeros_like(corr_matrix, dtype=np.bool), cmap=sns.diverging_palette(220, 10, as_cmap=True),
            square=True, ax=ax)
# Out:
# <AxesSubplot:>

# %%
# Threshold for removing correlated variables
threshold = 0.9
# Select columns with correlations above threshold
to_drop = [column for column in upper.columns if any(upper[column] > threshold)]
print('There are %d columns to remove.' % (len(to_drop)))
to_drop
# Out:
# There are 1 columns to remove.
# ['Tensile yield strength at 0.2% offset  (MPa)']

# %% [markdown]
# ## Data visulaization

# %% [markdown]
# ### Temper method

# %%
df1 = df_preprocessed['temper method'].value_counts(normalize=True)
df1 = df1.mul(100)
df1 = df1.rename('percentage').reset_index().sort_values('percentage', ascending=True)
df1 = df1.rename(columns={'index': 'Temper method'})

# %%
fig, ax = plt.subplots(figsize=(20,5))
ax = sns.barplot(x="Temper method", y="percentage",  data=df1, palette="viridis")
_ = plt.setp(ax.get_xticklabels(), rotation=90)  # Rotate labels

# %% [markdown]
# ### Processing Method

# %%
df2 = df_preprocessed['Processing Method'].value_counts(normalize=True)
df2 = df2.mul(100)
df2 = df2.rename('percentage').reset_index().sort_values('percentage', ascending=True)
df2 = df2.rename(columns={'index': 'Processing Method'})

# %%
fig, ax = plt.subplots(figsize=(20,5))
ax = sns.barplot(x="Processing Method", y="percentage",  data=df2, palette="viridis")
_ = plt.setp(ax.get_xticklabels(), rotation=90)  # Rotate labels

# %% [markdown]
# ## Features Engineering

# %% [markdown]
# ### Target Variable Analysis:  Is it Normal?

# %%
#histogram and normal probability plot
from scipy.stats import norm
from scipy import stats

# %% [markdown]
# #### Ultimate tensile strength

# %%
# df3 = df_processed['Ultimate tensile strength  (MPa)']
# hist = df3.hist(bins=3)
# sns.distplot(df_processed['Ultimate tensile strength  (MPa)'], kde=False, color='blue', bins=100)
# plt.xlabel('Ultimate tensile strength  (MPa)', fontsize=16)
# plt.ylabel('Frequency', fontsize=16)
# sns.histplot(data=df_processed, x='Ultimate tensile strength  (MPa)')

# %%
col='Ultimate tensile strength  (MPa)'
sns.distplot(df_preprocessed[col],fit=norm);
fig = plt.figure()
res = stats.probplot(df_preprocessed[col], plot=plt)

# %%
plt.figure(figsize=(10, 4))
plt.subplot(1, 2, 1)
sns.histplot(df_preprocessed[col], color="red", label="100% Equities", kde=True, stat="density", linewidth=0)
plt.xlabel('Properties')
plt.ylabel('Density')

plt.subplot(1, 2, 2)
res = stats.probplot(df_preprocessed[col], plot=plt)
plt.tight_layout()
plt.show()

# %% [markdown]
# - we have right-skewness and the data is a bit peak-y.
# - Let's apply a log transform on the data and see what happens...

# %% [markdown]
# #### Tensile yield strength

# %%
# df4 = df_processed['Tensile yield strength at 0.2% offset  (MPa)']
# hist = df3.hist(bins=3)
# sns.distplot(df_processed['Tensile yield strength at 0.2% offset  (MPa)'], kde=False, color='blue', bins=100)
# plt.xlabel('Tensile yield strength at 0.2% offset  (MPa)', fontsize=16)
# plt.ylabel('Frequency', fontsize=16)
# sns.histplot(data=df_processed, x='Tensile yield strength at 0.2% offset  (MPa)')

# %%
col='Tensile yield strength at 0.2% offset  (MPa)'
sns.distplot(df_preprocessed[col],fit=norm);
fig = plt.figure()
res = stats.probplot(df_preprocessed[col], plot=plt)

# %% [markdown]
# ### Normalize Target

# %%
import pandas as pd
from sklearn import preprocessing

# %%
data_scaled = df_preprocessed.copy(deep=True)

# %%
# apply normalization techniques by Column 1
column = 'Ultimate tensile strength  (MPa)'
# data_processed[column] = (data_processed[column] - data_processed[column].min()) / (data_processed[column].max() - data_processed[column].min())  

x = data_scaled[[column]].values #returns a numpy array
# scaler = preprocessing.MinMaxScaler()
scaler = preprocessing. StandardScaler()
x_scaled = scaler.fit_transform(x)
data_scaled[column] = x_scaled

sns.distplot(data_scaled[column],fit=norm);
fig = plt.figure()
res = stats.probplot(data_scaled[column], plot=plt)

# %%
from sklearn.preprocessing import PowerTransformer
from sklearn.preprocessing import QuantileTransformer
from sklearn.preprocessing import quantile_transform

# %%
rng = np.random.RandomState(0)


x = data_scaled[[column]].values #returns a numpy array
x_scaled=quantile_transform(x,n_quantiles=10, random_state=0, copy=True)
data_scaled[column] = x_scaled

sns.distplot(data_scaled[column],fit=norm);
fig = plt.figure()
res = stats.probplot(data_scaled[column], plot=plt)

# %%
# qt = QuantileTransformer(n_quantiles=500, output_distribution='normal',
#                          random_state=rng)


# X_trans_qt = qt.fit(X_train).transform(X_test)
# pipe = make_pipeline(QuantileTransformer(), LogisticRegression()).

# %%
# apply normalization techniques by Column 1
column = 'Tensile yield strength at 0.2% offset  (MPa)'
# x = data_processed[[column]].values #returns a numpy array
# min_max_scaler = preprocessing.MinMaxScaler()
# x_scaled = min_max_scaler.fit_transform(x)
# data_processed[column] = x_scaled

data_scaled[column] = np.log(data_scaled[column])

sns.distplot(data_scaled[column],fit=norm);
fig = plt.figure()
res = stats.probplot(data_scaled[column], plot=plt)

# %%
## Features Engineering

# %%
# from sklearn.model_selection import train_test_split

# %%
# col = 'Ultimate tensile strength  (MPa)'
# y = df_processed[col]
# X= df_processed[df_processed.columns.difference(['Ultimate tensile strength  (MPa)','Tensile yield strength at 0.2% offset  (MPa)'])]

# %%
# X_dummies = pd.get_dummies(X)
# train_features, valid_features, train_y, valid_y = train_test_split(X_dummies, y, test_size = 0.25, random_state = 1)

# %% [markdown]
# ## Model

# %%
 #Imports used by model   
from numpy import mean
from numpy import std    
from sklearn.model_selection import KFold
from sklearn.preprocessing import OrdinalEncoder 
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import RepeatedKFold
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import mean_absolute_error
import gc

# %%
class Normalizer(object):
    """Normalize a numpy array. """

    def __init__(self, array):
        """array is taken as a sample to calculate the mean and std"""
        self.mean = np.mean(array)
        self.std = np.std(array)

    def norm(self, array):
        return (array - self.mean) / self.std

    def denorm(self, normed_array):
        return normed_array * self.std + self.mean

    def state_dict(self):
        return {'mean': self.mean,
                'std': self.std}

    def load_state_dict(self, state_dict):
        self.mean = state_dict['mean']
        self.std = state_dict['std']

# %%
def getObjectFeature(df, col_name):
    
    if df[col_name].dtype!='object': # if it's not categorical..
        print('feature',col_name,'is not an object feature.')
        return df
    else:
        ordinal_enc_dict = {}
        df_ordinal = df.copy(deep=True)
        # Create dictionary for Ordinal encoders
        ordinal_enc_dict[col_name] = OrdinalEncoder()
        
        # Select the nin-null values in the column
      
        col = df[col_name]
        col_not_null = col[col.notnull()]
        reshaped_vals = col_not_null.values.reshape(-1, 1)

        # Encode the non-null values of the column
        encoded_vals = ordinal_enc_dict[col_name].fit_transform(reshaped_vals)

        ##Replace the column with ordinal values

        df_ordinal.loc[col.notnull(),col_name]  =np.squeeze(encoded_vals)
        print('+Encode: {} '.format(col_name))
  
        return df_ordinal
        
# and test the function...

# %%
# Function to calculate mean absolute error
def mae(y_true, y_pred):
    return np.mean(abs(y_true - y_pred))

# Takes in a model, trains the model, and evaluates the model on the test set
def fit_and_evaluate(model):
    
    # Train the model
    model.fit(X, y)
    
    # Make predictions and evalute
    model_pred = model.predict(X_test)
    model_mae = mae(y_test, model_pred)
    
    # Return the performance metric
    return model_mae

# %%
def plot_feature_importances(df, threshold = 0.95):
    """
    Plots 15 most important features and the cumulative importance of features.
    Prints the number of features needed to reach threshold cumulative importance.
    
    Parameters
    --------
    df : dataframe
        Dataframe of feature importances. Columns must be feature and importance
    threshold : float, default = 0.9
        Threshold for prining information about cumulative importances
        
    Return
    --------
    df : dataframe
        Dataframe ordered by feature importances with a normalized column (sums to 1)
        and a cumulative importance column
    
    """
    
    plt.rcParams['font.size'] = 18
    
    # Sort features according to importance
    df = df.sort_values('importance', ascending = False).reset_index()
    
    # Normalize the feature importances to add up to one
    df['importance_normalized'] = df['importance'] / df['importance'].sum()
    df['cumulative_importance'] = np.cumsum(df['importance_normalized'])

    # Make a horizontal bar chart of feature importances
    f,ax=plt.subplots(1,2,figsize=(30,12))
    #plt.figure(figsize = (10, 6))
    #ax = plt.subplot()
    
    # Need to reverse the index to plot most important on top
    ax[0].barh(list(reversed(list(df.index[:15]))), 
            df['importance_normalized'].head(15), 
            align = 'center', edgecolor = 'k')
    
    # Set the yticks and labels
    ax[0].set_yticks(list(reversed(list(df.index[:15]))))
    ax[0].set_yticklabels(df['feature'].head(15))
    
    

    # Plot labeling
    ax[0].set_title('Feature Importances')
    ax[0].set_ylabel('Normalized Importance')

    #plt.xlabel('Normalized Importance'); plt.title('Feature Importances')
    #plt.show()
   
    
    # Cumulative importance plot
    #plt.figure(figsize = (8, 10))
    plt.plot(list(range(len(df))), df['cumulative_importance'], 'r-')
    #plt.xlabel('Number of Features'); plt.ylabel('Cumulative Importance'); 
    ax[1].set_title('Cumulative Feature Importance')
    ax[1].set_ylabel('Cumulative Importance')
    ax[1].set_xlabel('Number of Features')
    #plt.title('Cumulative Feature Importance');
    plt.show();
    f.savefig('Feature_Importances_RF.png', dpi=300)
    importance_index = np.min(np.where(df['cumulative_importance'] > threshold))
    print('%d features required for %0.2f of cumulative importance' % (importance_index + 1, threshold))
    
    return df

# %%
column = 'Ultimate tensile strength  (MPa)'
y = df_preprocessed[[column]].values #returns a numpy array
# min_max_scaler = preprocessing.MinMaxScaler()
# y_scaled = min_max_scaler.fit_transform(y)

X= df_preprocessed[df_preprocessed.columns.difference(['Ultimate tensile strength  (MPa)','Tensile yield strength at 0.2% offset  (MPa)'])]

for col in list(X):
    if X[col].dtype=='object':
        X = getObjectFeature(X, col)     

train_features, valid_features, train_y, valid_y = train_test_split(X,y, test_size = 0.25, random_state = 1)
# Out:
# +Encode: Processing Method
# +Encode: temper method

# %% [markdown]
# ## Random Forest Regression

# %%
normalizer = Normalizer(y)

# %%
estimators = [10, 50, 100, 500, 1000, 5000]
mean_rfrs = []
std_rfrs_upper = []
std_rfrs_lower = []

cv = RepeatedKFold(n_splits=10, n_repeats=3, random_state=1)

np.random.seed(11111)
for i in estimators:
    model = RandomForestRegressor(n_estimators=i,max_depth=None)
    n_scores = cross_val_score(model,train_features, normalizer.norm(train_y),cv=cv,scoring='neg_mean_absolute_error', n_jobs=-1)
    print('estimators:',i)
#     print('explained variance scores for k=10 fold validation:',scores_rfr)
    print("Est. neg_mean_absolute_error: %0.2f (+/- %0.2f)" % (mean(n_scores), std(n_scores)*2))
    print('')
    mean_rfrs.append(mean(n_scores))
    std_rfrs_upper.append(mean(n_scores)+std(n_scores)*2) # for error plotting
    std_rfrs_lower.append(mean(n_scores)-std(n_scores)*2) # for error plotting
# Out:
# estimators: 10
# Est. neg_mean_absolute_error: -0.65 (+/- 0.14)
#
# estimators: 50
# Est. neg_mean_absolute_error: -0.64 (+/- 0.14)
#
# estimators: 100
# Est. neg_mean_absolute_error: -0.64 (+/- 0.13)
#
# estimators: 500
# Est. neg_mean_absolute_error: -0.64 (+/- 0.14)
#
# estimators: 1000
# Est. neg_mean_absolute_error: -0.64 (+/- 0.13)
#
# estimators: 5000
# Est. neg_mean_absolute_error: -0.64 (+/- 0.13)

# %%
# and plot...
fig = plt.figure(figsize=(12,8))
ax = fig.add_subplot(111)
ax.plot(estimators,mean_rfrs,marker='o',
       linewidth=4,markersize=12)
ax.fill_between(estimators,std_rfrs_lower,std_rfrs_upper,
                facecolor='green',alpha=0.3,interpolate=True)
# ax.set_ylim([-.3,1])
# ax.set_xlim([0,80])
plt.title('neg_mean_absolute_error of Random Forest Regressor')
plt.ylabel('neg_mean_absolute_error')
plt.xlabel('Trees in Forest')
plt.grid()
plt.show()
# Out:
# The history saving thread hit an unexpected error (OperationalError('attempt to write a readonly database',)).History will not be written to the database.

# %%
model = RandomForestRegressor(n_estimators=500,max_depth=None)
rf_model = model.fit(train_features, train_y)
y_pred = rf_model.predict(valid_features)

# %% [markdown]
# ### Features selection

# %%
# model is the trained model
importances = rf_model.feature_importances_
# train_features is the dataframe of training features
feature_names = list(X)

# %%
# Extract the feature importances into a dataframe
feature_results = pd.DataFrame({'feature': list(feature_names), 
                                'importance':importances})

# Show the top 10 most important
feature_results = feature_results.sort_values('importance', ascending = False).reset_index(drop=True)

feature_results.head(10)
# Out:
#              feature  importance
# 0      temper method    0.296687
# 1         Mg Nominal    0.219643
# 2         Cu Nominal    0.097042
# 3  Processing Method    0.092921
# 4         Si Nominal    0.061939
# 5         Mn Nominal    0.057858
# 6         Cr Nominal    0.031950
# 7         Zn Nominal    0.031906
# 8         Fe Nominal    0.019334
# 9         Ti Nominal    0.018021

# %%
# Find the features with zero importance
zero_features = list(feature_results[feature_results['importance'] == 0.0]['feature'])
print('There are %d features with 0.0 importance' % len(zero_features))
feature_results.tail()
# Drop features with zero importance
#X = X.drop(columns = zero_features)
# Out:
# There are 6 features with 0.0 importance
#            feature  importance
# 26  Si+Cu Nominal          0.0
# 27      Ga Nominal         0.0
# 28   Fe+Ni Nominal         0.0
# 29    V+Ti Nominal         0.0
# 30       W Nominal         0.0

# %%
norm_feature_importances = plot_feature_importances(feature_results)
# Out:
# 12 features required for 0.95 of cumulative importance

# %%
# Threshold for cumulative importance
threshold = 0.95
# Extract the features to keep
features_to_keep = list(norm_feature_importances[norm_feature_importances['cumulative_importance'] < threshold]['feature'])

# Create new datasets with smaller features
train_small = train_features[features_to_keep]
valid_small= valid_features[features_to_keep]

# %% [markdown]
# ### Grid Search  with Cross Validation

# %%
from pprint import pprint


# Create the parameter grid based on the results of random search 
param_grid = {
    'bootstrap': [True],
    'max_depth': [90, 100, 120],
    'max_features': ['auto'],
    'min_samples_leaf': [3, 4, 5],
    'min_samples_split': [ 10, 12],
    'n_estimators': [10, 50, 100, 500,1000]
}


# Create a base model
rf = RandomForestRegressor(random_state = 42,n_jobs=-1)
# define the evaluation procedure
cv =RepeatedKFold(n_splits=10, n_repeats=3, random_state=1)
# Instantiate the grid search model
grid_search = GridSearchCV(estimator = rf, param_grid = param_grid, 
                          cv = cv, n_jobs = -1, verbose = 2, return_train_score=True)

grid_result = grid_search.fit(train_small,  normalizer.norm(train_y))
# summarize the best score and configuration
print("Best: %f using %s" % (grid_result.best_score_, grid_result.best_params_))
# summarize all scores that were evaluated
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
    print("%f (%f) with: %r" % (mean, stdev, param))
# Out:
# Fitting 30 folds for each of 90 candidates, totalling 2700 fits
# Best: 0.191885 using {'bootstrap': True, 'max_depth': 90, 'max_features': 'auto', 'min_samples_leaf': 5, 'min_samples_split': 12, 'n_estimators': 100}
# 0.177484 (0.165099) with: {'bootstrap': True, 'max_depth': 90, 'max_features': 'auto', 'min_samples_leaf': 3, 'min_samples_split': 10, 'n_estimators': 10}
# 0.183570 (0.151892) with: {'bootstrap': True, 'max_depth': 90, 'max_features': 'auto', 'min_samples_leaf': 3, 'min_samples_split': 10, 'n_estimators': 50}
# 0.185824 (0.155819) with: {'bootstrap': True, 'max_depth': 90, 'max_features': 'auto', 'min_samples_leaf': 3, 'min_samples_split': 10, 'n_estimators': 100}
# 0.186812 (0.153774) with: {'bootstrap': True, 'max_depth': 90, 'max_features': 'auto', 'min_samples_leaf': 3, 'min_samples_split': 10, 'n_estimators': 500}
# ...

# %% [markdown]
# ### Evaluate Final Model on the Test Set

# %%
# Default model
default_model = RandomForestRegressor(random_state = 42, n_jobs=-1)

# Select the best model
final_model = grid_search.best_estimator_

pprint(final_model)
# Out:
# RandomForestRegressor(max_depth=90, min_samples_leaf=5, min_samples_split=12,
#                       n_jobs=-1, random_state=42)

# %%
# %%timeit -n 1 -r 5


default_model.fit(train_small,  normalizer.norm(train_y))
# Out:
# 353 ms ± 3.49 ms per loop (mean ± std. dev. of 5 runs, 1 loop each)

# %%
# %%timeit -n 1 -r 5
final_model.fit(train_small,  normalizer.norm(train_y))
# Out:
# 351 ms ± 4.47 ms per loop (mean ± std. dev. of 5 runs, 1 loop each)

# %%
default_pred = normalizer.denorm(default_model.predict(valid_small))
final_pred = normalizer.denorm(final_model.predict(valid_small))

print('Default model performance on the test set: MAE = %0.4f.' % mae(valid_y, default_pred))
print('Final model performance on the test set:   MAE = %0.4f.' % mae(valid_y, final_pred))
# Out:
# Default model performance on the test set: MAE = 128.4339.
# Final model performance on the test set:   MAE = 124.4482.

# %%
test_file= "test_results_RF_UTS.csv"
with open(test_file, "w") as f:
    writer = csv.writer(f)
    for value,pred in zip(valid_y.flatten(), final_pred):
        writer.writerow((value,pred ))

# %%
test_results = np.genfromtxt(test_file, delimiter=',', usecols=(0, 1), names=["x", "y"])

# %%
plt.figure(figsize=(10, 4))
plt.subplot(1, 2, 1)

 
# Density plot of the final predictions and the test values
sns.kdeplot(test_results['y'], label = 'Predictions')
sns.kdeplot(test_results['x'], label = 'Values')
plt.legend(loc="upper right", fontsize=15)
# Label the plot
plt.xlabel('Ultimate tensile strength  (MPa'); plt.ylabel('Density')
plt.title('Test Values and Predictions')

plt.subplot(1, 2, 2)

# Calculate the residuals 
residuals = test_results['y'] - test_results['x']


# Plot the residuals in a histogram
plt.hist(residuals, color = 'red', bins = 20,
         edgecolor = 'black')
plt.xlabel('Error'); plt.ylabel('Count')
plt.title('Distribution of Residuals')
plt.tight_layout()
plt.savefig('RF_training.png', dpi=600, transparent=True, bbox_inches='tight')

plt.show()

# %%
sns.kdeplot(
   test_results['y'], 
   fill=True, common_norm=False, palette="crest",
   alpha=.5, linewidth=0,
)
# Out:
# <AxesSubplot:ylabel='Density'>

# %% [markdown]
# ## Gradient boosting machine (GBM)  Regression

# %%
# define the model
model = GradientBoostingRegressor()
# define the evaluation procedure
cv = RepeatedKFold(n_splits=10, n_repeats=3, random_state=1)
# evaluate the model
n_scores = cross_val_score(model, train_features, train_y, scoring='neg_mean_absolute_error', cv=cv, n_jobs=-1)
print('MAE: %.3f (%.3f)' % (np.mean(n_scores), np.std(n_scores)))
# Out:
# MAE: -91.579 (7.781)

# %% [markdown]
# ###  Explore Number of Trees

# %%
# https://machinelearningmastery.com/gradient-boosting-machine-ensemble-in-python/
# get a list of models to evaluate
def get_models():
	models = dict()
	# define number of trees to consider
	n_trees = [10, 50, 100, 500, 1000, 5000]
	for n in n_trees:
		models[str(n)] = GradientBoostingRegressor(n_estimators=n)
	return models
 
# evaluate a given model using cross-validation
def evaluate_model(model, X, y):
	# define the evaluation procedure
	cv = RepeatedKFold(n_splits=10, n_repeats=3, random_state=1)
	# evaluate the model and collect the results
	scores = cross_val_score(model, X, y, scoring='neg_mean_absolute_error', cv=cv, n_jobs=-1)
	return scores
 

# get the models to evaluate
models = get_models()
# evaluate the models and store results
results, names = list(), list()
for name, model in models.items():
	# evaluate the model
	scores = evaluate_model(model,  train_features, train_y)
	# store the results
	results.append(scores)
	names.append(name)
	# summarize the performance along the way
	print('>%s %.3f (%.3f)' % (name, np.mean(scores), np.std(scores)))
# plot model performance for comparison
plt.boxplot(results, labels=names, showmeans=True)
plt.ylabel('scores')
plt.xlabel(' Number of Trees')
plt.show()
# Out:
# >10 -100.224 (8.256)
# >50 -93.839 (7.484)
# >100 -91.666 (7.746)
# >500 -87.076 (9.475)
# >1000 -86.704 (9.848)
# >5000 -86.694 (10.054)

# %% [markdown]
# ###  Learning Rate

# %%
# get a list of models to evaluate
def get_models():
	models = dict()
	# define learning rates to explore
	for i in [0.0001, 0.001, 0.01, 0.1, 1.0]:
		key = '%.4f' % i
		models[key] = GradientBoostingRegressor(learning_rate=i)
	return models

# evaluate a given model using cross-validation
def evaluate_model(model, X, y):
	# define the evaluation procedure
	cv = RepeatedKFold(n_splits=10, n_repeats=3, random_state=1)
	# evaluate the model and collect the results
	scores = cross_val_score(model, X, y, scoring='neg_mean_absolute_error', cv=cv, n_jobs=-1)
	return scores
 

# get the models to evaluate
models = get_models()
# evaluate the models and store results
results, names = list(), list()
for name, model in models.items():
	# evaluate the model
	scores = evaluate_model(model,  train_features, train_y)
	# store the results
	results.append(scores)
	names.append(name)
	# summarize the performance along the way
	print('>%s %.3f (%.3f)' % (name,  np.mean(scores), np.std(scores)))
# plot model performance for comparison
plt.boxplot(results, labels=names, showmeans=True)
plt.ylabel('scores')
plt.xlabel(' Learning Rate')
plt.show()
# Out:
# >0.0001 -110.889 (9.574)
# >0.0010 -109.417 (9.487)
# >0.0100 -100.645 (8.280)
# >0.1000 -91.625 (7.657)
# >1.0000 -90.268 (10.135)

# %% [markdown]
# ### Tree Depth

# %%
# get a list of models to evaluate
def get_models():
	models = dict()
	# define max tree depths to explore between 1 and 10
	for i in range(1,11):
		models[str(i)] = GradientBoostingRegressor(max_depth=i)
	return models

# evaluate a given model using cross-validation
def evaluate_model(model, X, y):
	# define the evaluation procedure
	cv = RepeatedKFold(n_splits=10, n_repeats=3, random_state=1)
	# evaluate the model and collect the results
	scores = cross_val_score(model, X, y, scoring='neg_mean_absolute_error', cv=cv, n_jobs=-1)
	return scores
 

# get the models to evaluate
models = get_models()
# evaluate the models and store results
results, names = list(), list()
for name, model in models.items():
	# evaluate the model
	scores = evaluate_model(model,  train_features, train_y)
	# store the results
	results.append(scores)
	names.append(name)
	# summarize the performance along the way
	print('>%s %.3f (%.3f)' % (name,  np.mean(scores), np.std(scores)))
# plot model performance for comparison
plt.boxplot(results, labels=names, showmeans=True)
plt.ylabel('scores')
plt.xlabel(' Tree Depth')
plt.show()
# Out:
# >1 -99.531 (8.488)
# >2 -94.883 (7.531)
# >3 -91.657 (7.783)
# >4 -89.189 (8.226)
# >5 -87.732 (8.876)
# >6 -87.814 (9.738)
# >7 -87.902 (9.599)
# >8 -88.931 (10.106)
# >9 -89.943 (10.081)
# >10 -91.100 (10.430)

# %% [markdown]
# ### Grid Search Hyperparameters

# %%
model = GradientBoostingRegressor()

# define the grid of values to search
grid = dict()
grid['n_estimators'] = [10, 50, 100, 500]
grid['learning_rate'] = [0.0001, 0.001, 0.01, 0.1, 1.0]
grid['subsample'] = [0.5, 0.7, 1.0]
grid['max_depth'] = [3, 7, 9]
# define the evaluation procedure
cv =RepeatedKFold(n_splits=10, n_repeats=3, random_state=1)
# define the grid search procedure
grid_search = GridSearchCV(estimator=model, param_grid=grid, n_jobs=-1, cv=cv, scoring='neg_mean_absolute_error')
# execute the grid search
grid_result = grid_search.fit(train_features, train_y)
# summarize the best score and configuration
print("Best: %f using %s" % (grid_result.best_score_, grid_result.best_params_))
# summarize all scores that were evaluated
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
    print("%f (%f) with: %r" % (mean, stdev, param))
# Out:
# Best: -87.089751 using {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 500, 'subsample': 1.0}
# -111.044953 (9.580470) with: {'learning_rate': 0.0001, 'max_depth': 3, 'n_estimators': 10, 'subsample': 0.5}
# -111.045176 (9.580257) with: {'learning_rate': 0.0001, 'max_depth': 3, 'n_estimators': 10, 'subsample': 0.7}
# -111.045110 (9.580572) with: {'learning_rate': 0.0001, 'max_depth': 3, 'n_estimators': 10, 'subsample': 1.0}
# -110.976208 (9.575099) with: {'learning_rate': 0.0001, 'max_depth': 3, 'n_estimators': 50, 'subsample': 0.5}
# -110.973881 (9.576307) with: {'learning_rate': 0.0001, 'max_depth': 3, 'n_estimators': 50, 'subsample': 0.7}
# -110.975785 (9.578007) with: {'learning_rate': 0.0001, 'max_depth': 3, 'n_estimators': 50, 'subsample': 1.0}
# -110.891393 (9.566746) with: {'learning_rate': 0.0001, 'max_depth': 3, 'n_estimators': 100, 'subsample': 0.5}
# -110.887103 (9.568461) with: {'learning_rate': 0.0001, 'max_depth': 3, 'n_estimators': 100, 'subsample': 0.7}
# ...

# %% [markdown]
# ### Evaluate Final Model on the Test Set

# %%
# Default model
default_model = GradientBoostingRegressor(random_state = 42)

# Select the best model
final_model = grid_search.best_estimator_

pprint(final_model)
# Out:
# GradientBoostingRegressor(n_estimators=500)

# %%
# %%timeit -n 1 -r 5
default_model.fit(train_features, train_y)
# Out:
# 64.2 ms ± 2.34 ms per loop (mean ± std. dev. of 5 runs, 1 loop each)

# %%
# %%timeit -n 1 -r 5
final_model.fit(train_features, train_y)
# Out:
# 313 ms ± 9.31 ms per loop (mean ± std. dev. of 5 runs, 1 loop each)

# %%
default_pred = default_model.predict(valid_features)
final_pred = final_model.predict(valid_features)

print('Default model performance on the test set: MAE = %0.4f.' % mae(valid_y, default_pred))
print('Final model performance on the test set:   MAE = %0.4f.' % mae(valid_y, final_pred))
# Out:
# Default model performance on the test set: MAE = 123.6221.
# Final model performance on the test set:   MAE = 129.6537.

# %%
test_file= "test_results_XGB_UTS.csv"
with open(test_file, "w") as f:
    writer = csv.writer(f)
    for value,pred in zip(valid_y.flatten(), final_pred):
        writer.writerow((value,pred ))

test_results = np.genfromtxt(test_file, delimiter=',', usecols=(0, 1), names=["x", "y"])

# %%
plt.figure(figsize=(10, 4))
plt.subplot(1, 2, 1)

# Density plot of the final predictions and the test values
sns.kdeplot(test_results['y'], label = 'Predictions')
sns.kdeplot(test_results['x'], label = 'Values')
plt.legend(loc="upper right", fontsize=15)
# Label the plot
plt.xlabel('Ultimate tensile strength  (MPa'); plt.ylabel('Density')
plt.title('Test Values and Predictions')

plt.subplot(1, 2, 2)

# Calculate the residuals 
residuals = test_results['y'] - test_results['x']

# Plot the residuals in a histogram
plt.hist(residuals, color = 'red', bins = 20,
         edgecolor = 'black')
plt.xlabel('Error'); plt.ylabel('Count')
plt.title('Distribution of Residuals')
plt.tight_layout()
plt.savefig('GBM_training.png', dpi=600, transparent=True, bbox_inches='tight')

plt.show()
